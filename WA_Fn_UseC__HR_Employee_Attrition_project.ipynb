# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
plt.pie(df['Attrition'].value_counts(),labels=df['Attrition'].value_counts().index,autopct='%1.2f%%',explode=[0.02,0.03])
plt.show()

# %%
Category=df.select_dtypes(include='object')
for i in Category:
  print(i)
  print(df[i].value_counts())
  print('='*100)
# Out:
# Attrition
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
# ...
# BusinessTravel
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64
# ...
# Department
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64
# ...
# EducationField
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64
# ...
# Gender
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64
# ...
# JobRole
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# ...

# %%
sns.set_palette('gist_rainbow_r')
plt.figure(figsize=(20,20),facecolor='white')
plotnumber=1
for i in Category:
  if plotnumber<=9:
    ax=plt.subplot(3,3,plotnumber)
    sns.countplot(x=df[i])
    plt.xlabel(i,fontsize=20)
    plt.xticks(rotation=30)
  plotnumber+=1
plt.tight_layout()
plt.show()

# %%
labels='Bachelor','Master','College','Below College','Doctor'
plt.pie(df['Education'].value_counts(),labels=labels,radius=2,explode=[0.1,0.1,0.15,0.2,0.3],autopct='%1.2f%%',shadow=True)
plt.show()

# %%
df['Education'].unique()
# Out:
# array([2, 1, 4, 3, 5])

# %%
df['EducationField'].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
df['Education'].value_counts()
# Out:
# Education
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: count, dtype: int64

# %%
plt.pie(df['Education'].value_counts(),labels=df['Education'].value_counts().index,explode=[0.1,0.1,0.15,0.2,0.3],autopct='%1.2f%%',shadow=True)
plt.show()

# %%
df['Department'].value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
plt.pie(df['Department'].value_counts(),labels=df['Department'].value_counts().index,radius=2,explode=[0.1,0.15,0.2],autopct='%1.2f%%',shadow=True)
plt.show()

# %%
pd.crosstab([df.Education],[df.Department],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_8c761_row0_col0 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# #T_8c761_row0_col1 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_8c761_row0_col2 {
#   background-color: #ebf566;
#   color: #000000;
# }
# #T_8c761_row0_col3 {
#   background-color: #eaf466;
#   color: #000000;
# }
# #T_8c761_row1_col0, #T_8c761_row1_col2, #T_8c761_row1_col3 {
#   background-color: #d5ea66;
#   color: #000000;
# }
# #T_8c761_row1_col1 {
#   background-color: #d6eb66;
#   color: #000000;
# }
# #T_8c761_row2_col0 {
#   background-color: #99cc66;
#   color: #000000;
# }
# #T_8c761_row2_col1 {
#   background-color: #a0d066;
#   color: #000000;
# }
# #T_8c761_row2_col2 {
#   background-color: #a6d266;
#   color: #000000;
# }
# #T_8c761_row2_col3 {
#   background-color: #a1d066;
#   color: #000000;
# }
# #T_8c761_row3_col0 {
#   background-color: #cce666;
#   color: #000000;
# }
# #T_8c761_row3_col1 {
#   background-color: #c2e066;
#   color: #000000;
# ...

# %%
pd.crosstab([df.Education],[df.Department,df.Attrition],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_18258_row0_col0 {
#   background-color: #f5fa66;
#   color: #000000;
# }
# #T_18258_row0_col1, #T_18258_row4_col0, #T_18258_row4_col1, #T_18258_row4_col2, #T_18258_row4_col3, #T_18258_row4_col4, #T_18258_row4_col5, #T_18258_row4_col6 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_18258_row0_col2 {
#   background-color: #e9f466;
#   color: #000000;
# }
# #T_18258_row0_col3 {
#   background-color: #e0f066;
#   color: #000000;
# }
# #T_18258_row0_col4 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_18258_row0_col5 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_18258_row0_col6 {
#   background-color: #eaf466;
#   color: #000000;
# }
# #T_18258_row1_col0, #T_18258_row1_col4 {
#   background-color: #d6eb66;
#   color: #000000;
# }
# #T_18258_row1_col1, #T_18258_row3_col1 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_18258_row1_col2, #T_18258_row1_col6 {
#   background-color: #d5ea66;
# ...

# %%
df['EducationField'].value_counts()
# Out:
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
plt.pie(df['EducationField'].value_counts(),labels=df['EducationField'].value_counts().index,radius=2,autopct='%1.2f%%',explode=[0.1,0.1,0.125,0.15,0.15,0.175],shadow=True)
plt.show()

# %%
pd.crosstab([df.Education],[df.EducationField],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_da472_row0_col0, #T_da472_row1_col0, #T_da472_row4_col0, #T_da472_row4_col1, #T_da472_row4_col2, #T_da472_row4_col3, #T_da472_row4_col4, #T_da472_row4_col5, #T_da472_row4_col6 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_da472_row0_col1, #T_da472_row0_col6 {
#   background-color: #eaf466;
#   color: #000000;
# }
# #T_da472_row0_col2 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_da472_row0_col3 {
#   background-color: #e4f266;
#   color: #000000;
# }
# #T_da472_row0_col4 {
#   background-color: #f3f966;
#   color: #000000;
# }
# #T_da472_row0_col5 {
#   background-color: #e0f066;
#   color: #000000;
# }
# #T_da472_row1_col1 {
#   background-color: #d4ea66;
#   color: #000000;
# }
# #T_da472_row1_col2 {
#   background-color: #e7f366;
#   color: #000000;
# }
# #T_da472_row1_col3 {
#   background-color: #d0e866;
#   color: #000000;
# }
# #T_da472_row1_col4 {
#   background-color: #c7e366;
#   color: #000000;
# }
# ...

# %%
pd.crosstab([df.Department],[df.EducationField],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_9d3f1_row0_col0, #T_9d3f1_row2_col2, #T_9d3f1_row3_col0, #T_9d3f1_row3_col1, #T_9d3f1_row3_col2, #T_9d3f1_row3_col3, #T_9d3f1_row3_col4, #T_9d3f1_row3_col5, #T_9d3f1_row3_col6 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_9d3f1_row0_col1, #T_9d3f1_row0_col2, #T_9d3f1_row0_col3, #T_9d3f1_row0_col4, #T_9d3f1_row0_col5, #T_9d3f1_row0_col6, #T_9d3f1_row1_col0, #T_9d3f1_row1_col2, #T_9d3f1_row2_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_9d3f1_row1_col1 {
#   background-color: #48a366;
#   color: #f1f1f1;
# }
# #T_9d3f1_row1_col3 {
#   background-color: #399c66;
#   color: #f1f1f1;
# }
# #T_9d3f1_row1_col4 {
#   background-color: #3a9c66;
#   color: #f1f1f1;
# }
# #T_9d3f1_row1_col5 {
#   background-color: #4ba566;
#   color: #f1f1f1;
# }
# #T_9d3f1_row1_col6 {
#   background-color: #5cae66;
#   color: #f1f1f1;
# }
# #T_9d3f1_row2_col1 {
#   background-color: #c5e266;
#   color: #000000;
# }
# #T_9d3f1_row2_col3 {
# ...

# %%
plt.figure(figsize=(15,7))
sns.countplot(x=df['JobRole'],palette='husl')
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_2037/3079859137.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['JobRole'],palette='husl')

# %%
pd.crosstab([df.JobRole],[df.Department],margins=True).style.background_gradient(cmap='gist_rainbow_r')
# Out:
# <style type="text/css">
# #T_c6ddf_row0_col0, #T_c6ddf_row0_col2, #T_c6ddf_row1_col1, #T_c6ddf_row1_col2, #T_c6ddf_row1_col3, #T_c6ddf_row2_col0, #T_c6ddf_row2_col2, #T_c6ddf_row4_col0, #T_c6ddf_row4_col2, #T_c6ddf_row5_col0, #T_c6ddf_row5_col2, #T_c6ddf_row6_col0, #T_c6ddf_row6_col2, #T_c6ddf_row7_col0, #T_c6ddf_row7_col1, #T_c6ddf_row8_col0, #T_c6ddf_row8_col1 {
#   background-color: #ff00bf;
#   color: #f1f1f1;
# }
# #T_c6ddf_row0_col1 {
#   background-color: #8600ff;
#   color: #f1f1f1;
# }
# #T_c6ddf_row0_col3, #T_c6ddf_row3_col1 {
#   background-color: #f300ff;
#   color: #f1f1f1;
# }
# #T_c6ddf_row1_col0 {
#   background-color: #ffc400;
#   color: #000000;
# }
# #T_c6ddf_row2_col1 {
#   background-color: #0033ff;
#   color: #f1f1f1;
# }
# #T_c6ddf_row2_col3 {
#   background-color: #7600ff;
#   color: #f1f1f1;
# }
# #T_c6ddf_row3_col0 {
#   background-color: #5000ff;
#   color: #f1f1f1;
# }
# #T_c6ddf_row3_col2, #T_c6ddf_row5_col1 {
#   background-color: #cd00ff;
# ...

# %%
pd.crosstab([df.JobRole,df.Department],[df.Attrition],margins=True).style.background_gradient(cmap='gist_rainbow_r')
# Out:
# <style type="text/css">
# #T_80240_row0_col0, #T_80240_row6_col2 {
#   background-color: #c200ff;
#   color: #f1f1f1;
# }
# #T_80240_row0_col1 {
#   background-color: #ff00f0;
#   color: #f1f1f1;
# }
# #T_80240_row0_col2 {
#   background-color: #cd00ff;
#   color: #f1f1f1;
# }
# #T_80240_row1_col0 {
#   background-color: #ff00e0;
#   color: #f1f1f1;
# }
# #T_80240_row1_col1, #T_80240_row7_col2, #T_80240_row10_col2 {
#   background-color: #fe00ff;
#   color: #f1f1f1;
# }
# #T_80240_row1_col2, #T_80240_row4_col2 {
#   background-color: #ff00e5;
#   color: #f1f1f1;
# }
# #T_80240_row2_col0 {
#   background-color: #7000ff;
#   color: #f1f1f1;
# }
# #T_80240_row2_col1 {
#   background-color: #0028ff;
#   color: #f1f1f1;
# }
# #T_80240_row2_col2 {
#   background-color: #5500ff;
#   color: #f1f1f1;
# }
# #T_80240_row3_col0, #T_80240_row3_col1, #T_80240_row3_col2 {
#   background-color: #ff00bf;
#   color: #f1f1f1;
# }
# #T_80240_row4_col0, #T_80240_row10_col0 {
# ...

# %%
numeric=df.select_dtypes(exclude='object')
numeric
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41       1102                 1          2              1
# 1      49        279                 8          1              1
# 2      37       1373                 2          2              1
# 3      33       1392                 3          4              1
# 4      27        591                 2          1              1
# ...   ...        ...               ...        ...            ...
# 1465   36        884                23          2              1
# 1466   39        613                 6          1              1
# 1467   27        155                 4          3              1
# 1468   49       1023                 2          3              1
# 1469   34        628                 8          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0                  1                        2          94               3
# ...

# %%
sns.set_palette('gist_rainbow_r')
plt.figure(figsize=(20,50),facecolor='white')
plotnumber=1
numeric_int=df.select_dtypes(exclude='object')
for i in numeric:
    if plotnumber<=25:
      ax=plt.subplot(9,3,plotnumber)
      sns.boxplot(x=df[i])
      plt.xlabel(i,fontsize=20)
      plt.xticks(rotation=30)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %%
sns.set_palette('gist_rainbow_r')
plt.figure(figsize=(20,50),facecolor='white')
plotnumber=1
numeric_int=df.select_dtypes(exclude='object')
for i in numeric:
    if plotnumber<=25:
      ax=plt.subplot(9,3,plotnumber)
      sns.violinplot(x=df[i])
      plt.xlabel(i,fontsize=20)
      plt.xticks(rotation=30)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %%
sns.set_palette('gist_rainbow_r')
plt.figure(figsize=(20,50),facecolor='white')
plotnumber=1
numeric_int=df.select_dtypes(exclude='object')
for i in numeric:
    if plotnumber<=25:
      ax=plt.subplot(9,3,plotnumber)
      sns.distplot(x=df[i])
      plt.xlabel(i,fontsize=20)
      plt.xticks(rotation=30)
    plotnumber+=1
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2037/2772123252.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[i])
# /tmp/ipykernel_2037/2772123252.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[i])
# /tmp/ipykernel_2037/2772123252.py:8: UserWarning:
#
# ...

# %%
plt.subplots(figsize=(12,6))
sns.countplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set_palette('hsv')
plt.figure(figsize=(18,8))
sns.countplot(x='Age',hue='Attrition',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=df['TotalWorkingYears'],y=df['MonthlyIncome'],errorbar=None)
plt.xlabel('TotalWorkingYears', fontsize=20)
plt.ylabel('MonthlyIncome',fontsize=20)
plt.title('TotalWorkingYearsvsMonthlyIncome',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='Attrition',y='MonthlyIncome',data=df,errorbar=None)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='Attrition',y='YearsSinceLastPromotion',data=df,errorbar=None)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.show()
